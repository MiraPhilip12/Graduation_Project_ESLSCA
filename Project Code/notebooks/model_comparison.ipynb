# %% [markdown]
# ## Model Comparison for Acting Performance Assessment
# ### This notebook compares different deep learning models for action recognition and performance assessment."

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import tensorflow as tf

from models.model_trainer import ModelTrainer
from models.cnn_lstm_model import CNNLSTMModel
from models.lstm_model import LSTMModel
from models.bilstm_model import BiLSTMModel
from models.gru_model import GRUModel
from models.rnn_model import RNNModel
from models.cnn_rnn_model import CNNRNNModel
from models.keras_model import KerasModel
from models.pycaret_model import PyCaretModel
from utils.data_loader import DataLoader
from utils.visualization import VisualizationUtils

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("All imports successful!")
# Out:
# All imports successful!

# %%
# Initialize data loader with correct path
data_loader = DataLoader(dataset_path="../Dataset")

# Print path info
print(f"Looking for dataset at: {data_loader.dataset_path.absolute()}")
print(f"Path exists: {data_loader.dataset_path.exists()}")

# Load dataset
print("\nLoading dataset...")
X, y, y_action, paths = data_loader.prepare_dataset(
    max_videos_per_class=5,  # Use 5 videos per class
    feature_type='aggregated'
)

# Check if data was loaded successfully
if X is None:
    print("❌ No data loaded! Check your dataset path and structure.")
else:
    print(f"\n✅ Dataset shape: {X.shape}")
    print(f"✅ Labels shape: {y.shape}")
    print(f"✅ Number of classes: {len(np.unique(y))}")
    print(f"✅ Class distribution: {np.bincount(y)}")
    print(f"✅ Number of videos: {len(paths)}")
    
    # Data quality check
    print(f"\nData quality check:")
    print(f"  - X dtype: {X.dtype}")
    print(f"  - Contains NaN: {np.isnan(X).any()}")
    print(f"  - Contains Inf: {np.isinf(X).any()}")
    print(f"  - Min value: {X.min():.3f}")
    print(f"  - Max value: {X.max():.3f}")
# Out:
# Looking for dataset at: c:\Graduation Project\V8\notebooks\..\Dataset
# Path exists: True
#
# Loading dataset...
# Processing Backhand Lob - Good Performance: BackhandLob1_Good.mp4
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Backhand Lob - Good Performance: BackhandLob2_Good.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 131ms/step
# Processing Backhand Lob - Good Performance: BackhandLob3_Good.mp4
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# Processing Backhand Lob - Good Performance: BackhandLob4_Good.mp4
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 37ms/step
# Processing Backhand Lob - Good Performance: BackhandLob5_Good.mp4
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# Processing Backhand Lob - Moderate Performance: BackhandLob1_Moderate.mp4
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# Processing Backhand Lob - Moderate Performance: BackhandLob2_Moderate.mp4
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Backhand Lob - Moderate Performance: BackhandLob3_Moderate.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Backhand Lob - Moderate Performance: BackhandLob4_Moderate.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# Processing Backhand Lob - Moderate Performance: BackhandLob5_Moderate.mp4
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Backhand Lob - Bad Performance: BackhandLob1_Bad.mp4
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Backhand Lob - Bad Performance: BackhandLob2_Bad.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Processing Backhand Lob - Bad Performance: BackhandLob3_Bad.mp4
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 51ms/step
# Processing Backhand Lob - Bad Performance: BackhandLob4_Bad.mp4
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# Processing Backhand Lob - Bad Performance: BackhandLob5_Bad.mp4
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Backhand - Good Performance: Backhand1_Good.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# Processing Backhand - Good Performance: Backhand2_Good.mp4
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# Processing Backhand - Good Performance: Backhand3_Good.mp4
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# Processing Backhand - Good Performance: Backhand4_Good.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Backhand - Good Performance: Backhand5_Good.mp4
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# Processing Backhand - Moderate Performance: Backhand1_Moderate.mp4
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# Processing Backhand - Moderate Performance: Backhand2_Moderate.mp4
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# Processing Backhand - Moderate Performance: Backhand3_Moderate.mp4
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 12ms/step
# Processing Backhand - Moderate Performance: Backhand4_Moderate.mp4
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Backhand - Moderate Performance: Backhand5_Moderate.mp4
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Backhand - Bad Performance: Backhand1_Bad.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Backhand - Bad Performance: Backhand2_Bad.mp4
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Backhand - Bad Performance: Backhand3_Bad.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Backhand - Bad Performance: Backhand4_Bad.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# Processing Backhand - Bad Performance: Backhand5_Bad.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# Processing Check The Watch - Good Performance: CheckTheWatch_1_Good.mp4
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# Processing Check The Watch - Good Performance: CheckTheWatch_2_Good.mp4
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# Processing Check The Watch - Good Performance: CheckTheWatch_3_Good.mp4
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# Processing Check The Watch - Good Performance: CheckTheWatch_4_Good.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Check The Watch - Good Performance: CheckTheWatch_5_Good.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# Processing Check The Watch - Moderate Performance: CheckTheWatch1_Moderate.mp4
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Check The Watch - Moderate Performance: CheckTheWatch2_Moderate.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Check The Watch - Moderate Performance: CheckTheWatch3_Moderate.mp4
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Check The Watch - Moderate Performance: CheckTheWatch4_Moderate.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Check The Watch - Moderate Performance: CheckTheWatch5_Moderate.mp4
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# Processing Check The Watch - Bad Performance: CheckTheWatch1_Bad.mp4
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# Processing Check The Watch - Bad Performance: CheckTheWatch2_Bad.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# Processing Check The Watch - Bad Performance: CheckTheWatch3_Bad.mp4
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Check The Watch - Bad Performance: CheckTheWatch4_Bad.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# Processing Check The Watch - Bad Performance: CheckTheWatch5_Bad.mp4
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Clapping - Good Performance: Clapping1_Good.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Clapping - Good Performance: Clapping2_Good.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Clapping - Good Performance: Clapping3_Good.mp4
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Clapping - Good Performance: Clapping4_Good.mp4
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Clapping - Good Performance: Clapping5_Good.mp4
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 10ms/step
# Processing Clapping - Moderate Performance: Clapping1_Moderate.mp4
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Clapping - Moderate Performance: Clapping2_Moderate.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Clapping - Moderate Performance: Clapping3_Moderate.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Processing Clapping - Moderate Performance: Clapping4_Moderate.mp4
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# Processing Clapping - Moderate Performance: Clapping5_Moderate.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 37ms/step
# Processing Clapping - Bad Performance: Clapping1_Bad.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# Processing Clapping - Bad Performance: Clapping2_Bad.mp4
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# ...
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Smash - Bad Performance: Smash3_Bad.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# Processing Smash - Bad Performance: Smash4_Bad.mp4
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Smash - Bad Performance: Smash5_Bad.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Thumbs Up - Good Performance: ThumbsUp1_Good.mp4
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Thumbs Up - Good Performance: ThumbsUp2_Good.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Thumbs Up - Good Performance: ThumbsUp3_Good.mp4
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# Processing Thumbs Up - Good Performance: ThumbsUp4_Good.mp4
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Thumbs Up - Good Performance: ThumbsUp5_Good.mp4
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Thumbs Up - Moderate Performance: ThumbsUp1_Moderate.mp4
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# Processing Thumbs Up - Moderate Performance: ThumbsUp2_Moderate.mp4
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Thumbs Up - Moderate Performance: ThumbsUp3_Moderate.mp4
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# Processing Thumbs Up - Moderate Performance: ThumbsUp4_Moderate.mp4
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# Processing Thumbs Up - Moderate Performance: ThumbsUp5_Moderate.mp4
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Thumbs Up - Bad Performance: ThumbsUp1_Bad.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 15ms/step
# Processing Thumbs Up - Bad Performance: ThumbsUp2_Bad.mp4
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# Processing Thumbs Up - Bad Performance: ThumbsUp3_Bad.mp4
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# Processing Thumbs Up - Bad Performance: ThumbsUp4_Bad.mp4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 14ms/step
# Processing Thumbs Up - Bad Performance: ThumbsUp5_Bad.mp4
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 16ms/step
# Aligning features...
# Total features: 180
# Dataset prepared: 150 samples, 180 features
# Class distribution: [50 50 50]
#
# ✅ Dataset shape: (150, 180)
# ✅ Labels shape: (150,)
# ✅ Number of classes: 3
# ✅ Class distribution: [50 50 50]
# ✅ Number of videos: 150
#
# Data quality check:
#   - X dtype: float64
#   - Contains NaN: False
#   - Contains Inf: False
#   - Min value: -0.796
#   - Max value: 1.085

# %%
# Only run if data loaded successfully
if X is not None:
    # Visualize class distribution
    viz = VisualizationUtils()
    fig = viz.plot_class_distribution(y, class_names=['Bad', 'Moderate', 'Good'])
    plt.show()
else:
    print("Cannot visualize - no data loaded")

# %%
# Only run if data loaded successfully
if X is not None:
    # Split data
    X_train, X_val, X_test, y_train, y_val, y_test = data_loader.split_data(
        X, y, test_size=0.2, val_size=0.1
    )

    print(f"\nTraining set: {X_train.shape}")
    print(f"Validation set: {X_val.shape}")
    print(f"Test set: {X_test.shape}")
    
    print(f"\nTraining class distribution: {np.bincount(y_train)}")
    print(f"Validation class distribution: {np.bincount(y_val)}")
    print(f"Test class distribution: {np.bincount(y_test)}")
else:
    print("Cannot split - no data loaded")
# Out:
# Train: 105, Val: 15, Test: 30
#
# Training set: (105, 180)
# Validation set: (15, 180)
# Test set: (30, 180)
#
# Training class distribution: [35 35 35]
# Validation class distribution: [5 5 5]
# Test class distribution: [5 5 5]

# %%
# Only run if data loaded successfully
if X is not None:
    # Initialize model trainer
    trainer = ModelTrainer(models_dir="../saved_models")

    # Input shape for flat features
    input_shape = (X_train.shape[1],)

    # Initialize models
    models = trainer.initialize_models(input_shape, num_classes=3)
    print(f"Initialized {len(models)} models:")
    for name in models.keys():
        print(f"  - {name}")
else:
    print("Cannot initialize models - no data loaded")
# Out:
# Initialized 8 models:
#   - CNN_LSTM
#   - LSTM
#   - BiLSTM
#   - GRU
#   - RNN
#   - CNN_RNN
#   - Keras_Deep
#   - Keras_Medium

# %%
# Only run if data loaded successfully
if X is not None:

    # -----------------------------
    # 1️⃣ Basic sanity checks
    # -----------------------------
    print("Checking dataset shapes...")
    print("X_train:", X_train.shape)
    print("y_train:", y_train.shape)
    print("X_val:", X_val.shape if X_val is not None else None)
    print("y_val:", y_val.shape if y_val is not None else None)

    assert len(X_train) == len(y_train), "Train data mismatch!"
    if X_val is not None:
        assert len(X_val) == len(y_val), "Validation data mismatch!"

    # -----------------------------
    # 2️⃣ Automatically detect classes
    # -----------------------------
    import numpy as np
    num_classes = len(np.unique(y_train))
    print("Detected classes:", num_classes)

    # -----------------------------
    # 3️⃣ Ensure correct label format
    # -----------------------------
    from tensorflow.keras.utils import to_categorical

    if len(y_train.shape) == 1:  # If labels are integers
        print("Converting labels to categorical...")
        y_train = to_categorical(y_train, num_classes)
        if y_val is not None:
            y_val = to_categorical(y_val, num_classes)
        if y_test is not None:
            y_test = to_categorical(y_test, num_classes)

    # -----------------------------
    # 4️⃣ Initialize trainer
    # -----------------------------
    trainer = ModelTrainer(models_dir="../saved_models")

    input_shape = (X_train.shape[1],)

    models = trainer.initialize_models(
        input_shape=input_shape,
        num_classes=num_classes
    )

    print(f"Initialized {len(models)} models:")
    for name in models.keys():
        print(f"  - {name}")

    # -----------------------------
    # 5️⃣ Train models
    # -----------------------------
    results = trainer.train_all_models(
        X_train, y_train,
        X_val, y_val,
        X_test, y_test,
        epochs=30,
        batch_size=8
    )

else:
    print("Cannot initialize models - no data loaded")
# Out:
# Checking dataset shapes...
# X_train: (105, 180)
# y_train: (105,)
# X_val: (15, 180)
# y_val: (15,)
# Detected classes: 3
# Converting labels to categorical...
# Initialized 8 models:
#   - CNN_LSTM
#   - LSTM
#   - BiLSTM
#   - GRU
#   - RNN
#   - CNN_RNN
#   - Keras_Deep
#   - Keras_Medium
#
# ==================================================
# Training CNN_LSTM...
# ==================================================
# Epoch 1/30
# 14/14 [==============================] - 4s 57ms/step - loss: 2.2784 - accuracy: 0.3905 - val_loss: 1.7220 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 2/30
# 14/14 [==============================] - 0s 6ms/step - loss: 2.0720 - accuracy: 0.4571 - val_loss: 1.7156 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.8278 - accuracy: 0.4476 - val_loss: 1.7075 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 4/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.7883 - accuracy: 0.4476 - val_loss: 1.6982 - val_accuracy: 0.2667 - lr: 0.0010
# Epoch 5/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.7590 - accuracy: 0.5143 - val_loss: 1.6875 - val_accuracy: 0.2667 - lr: 0.0010
# Epoch 6/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.7176 - accuracy: 0.4667 - val_loss: 1.6756 - val_accuracy: 0.2667 - lr: 0.0010
# Epoch 7/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.6209 - accuracy: 0.5619 - val_loss: 1.6619 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 8/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.5361 - accuracy: 0.5905 - val_loss: 1.6507 - val_accuracy: 0.2667 - lr: 0.0010
# Epoch 9/30
# 14/14 [==============================] - 0s 9ms/step - loss: 1.5645 - accuracy: 0.5810 - val_loss: 1.6381 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 10/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.5169 - accuracy: 0.5810 - val_loss: 1.6262 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 11/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.4162 - accuracy: 0.6286 - val_loss: 1.6193 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 12/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.5553 - accuracy: 0.5143 - val_loss: 1.6067 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 13/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.4657 - accuracy: 0.6000 - val_loss: 1.5816 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 14/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.3336 - accuracy: 0.6381 - val_loss: 1.5622 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 15/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.3935 - accuracy: 0.6381 - val_loss: 1.5503 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 16/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.4959 - accuracy: 0.6095 - val_loss: 1.5343 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 17/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.3268 - accuracy: 0.6286 - val_loss: 1.5062 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 18/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.2727 - accuracy: 0.6381 - val_loss: 1.4789 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 19/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.2184 - accuracy: 0.6952 - val_loss: 1.4586 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 20/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1283 - accuracy: 0.7524 - val_loss: 1.4332 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 21/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.2738 - accuracy: 0.6381 - val_loss: 1.4189 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 22/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.2027 - accuracy: 0.6667 - val_loss: 1.3837 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 23/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1650 - accuracy: 0.6571 - val_loss: 1.3574 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 24/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.2219 - accuracy: 0.6571 - val_loss: 1.3524 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 25/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1770 - accuracy: 0.7143 - val_loss: 1.3408 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 26/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1542 - accuracy: 0.6952 - val_loss: 1.3017 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 27/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1073 - accuracy: 0.7333 - val_loss: 1.2562 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 28/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1405 - accuracy: 0.7143 - val_loss: 1.2294 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 29/30
# 14/14 [==============================] - 0s 11ms/step - loss: 1.1654 - accuracy: 0.6667 - val_loss: 1.1627 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 30/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1591 - accuracy: 0.6952 - val_loss: 1.1227 - val_accuracy: 0.8000 - lr: 0.0010
# Warning: Length mismatch - y_test: 15, y_pred: 30
#
# CNN_LSTM Results:
# Accuracy: 0.3333
# Precision: 0.2222
# Recall: 0.3333
# F1-Score: 0.2641
#
# ==================================================
# Training LSTM...
# ==================================================
# Epoch 1/30
# 14/14 [==============================] - 9s 113ms/step - loss: 1.2131 - accuracy: 0.3524 - val_loss: 1.0985 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.3033 - accuracy: 0.3048 - val_loss: 1.0984 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 3/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.2308 - accuracy: 0.3714 - val_loss: 1.0988 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.3024 - accuracy: 0.2476 - val_loss: 1.0987 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 5/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.2408 - accuracy: 0.3238 - val_loss: 1.0985 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 6/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1704 - accuracy: 0.3714 - val_loss: 1.0987 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 7/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1244 - accuracy: 0.3714 - val_loss: 1.0988 - val_accuracy: 0.2667 - lr: 0.0010
# Epoch 8/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0761 - accuracy: 0.4000 - val_loss: 1.0986 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 9/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.2301 - accuracy: 0.4095 - val_loss: 1.0986 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 10/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1903 - accuracy: 0.3619 - val_loss: 1.0986 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 11/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1936 - accuracy: 0.3905 - val_loss: 1.0990 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 12/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.1851 - accuracy: 0.3714 - val_loss: 1.0987 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Warning: Length mismatch - y_test: 15, y_pred: 30
#
# LSTM Results:
# Accuracy: 0.3333
# Precision: 0.2222
# Recall: 0.3333
# F1-Score: 0.2402
#
# ==================================================
# Training BiLSTM...
# ==================================================
# Epoch 1/30
# 14/14 [==============================] - 15s 210ms/step - loss: 1.3471 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/30
# 14/14 [==============================] - 0s 13ms/step - loss: 1.2518 - accuracy: 0.3524 - val_loss: 1.0986 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/30
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2715 - accuracy: 0.3619 - val_loss: 1.0987 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/30
# 14/14 [==============================] - 0s 25ms/step - loss: 1.2112 - accuracy: 0.3429 - val_loss: 1.0992 - val_accuracy: 0.2667 - lr: 0.0010
# Epoch 5/30
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2029 - accuracy: 0.4095 - val_loss: 1.0999 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 6/30
# 14/14 [==============================] - 0s 11ms/step - loss: 1.1464 - accuracy: 0.3810 - val_loss: 1.0997 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 7/30
# 14/14 [==============================] - 0s 13ms/step - loss: 1.0765 - accuracy: 0.4857 - val_loss: 1.0992 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 8/30
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2322 - accuracy: 0.3619 - val_loss: 1.0984 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 9/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.1455 - accuracy: 0.4286 - val_loss: 1.0976 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 10/30
# 14/14 [==============================] - 0s 13ms/step - loss: 1.2729 - accuracy: 0.3238 - val_loss: 1.0975 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 11/30
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2212 - accuracy: 0.3333 - val_loss: 1.0978 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 12/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.1421 - accuracy: 0.3619 - val_loss: 1.0979 - val_accuracy: 0.2667 - lr: 5.0000e-04
# Epoch 13/30
# 14/14 [==============================] - 0s 13ms/step - loss: 1.1202 - accuracy: 0.4667 - val_loss: 1.0957 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 14/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.1463 - accuracy: 0.4000 - val_loss: 1.0931 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 15/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.1291 - accuracy: 0.3810 - val_loss: 1.0901 - val_accuracy: 0.2667 - lr: 5.0000e-04
# Epoch 16/30
# 14/14 [==============================] - 0s 20ms/step - loss: 1.1139 - accuracy: 0.4095 - val_loss: 1.0873 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 17/30
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2004 - accuracy: 0.4000 - val_loss: 1.0821 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 18/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0959 - accuracy: 0.4095 - val_loss: 1.0765 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 19/30
# 14/14 [==============================] - 0s 14ms/step - loss: 1.1349 - accuracy: 0.3714 - val_loss: 1.0691 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 20/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0718 - accuracy: 0.4667 - val_loss: 1.0617 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 21/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.1069 - accuracy: 0.4381 - val_loss: 1.0528 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 22/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.1455 - accuracy: 0.3524 - val_loss: 1.0402 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 23/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0612 - accuracy: 0.4381 - val_loss: 1.0291 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 24/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.1838 - accuracy: 0.3714 - val_loss: 1.0161 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 25/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.9783 - accuracy: 0.4857 - val_loss: 1.0022 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 26/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0986 - accuracy: 0.4286 - val_loss: 0.9857 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 27/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0723 - accuracy: 0.4857 - val_loss: 0.9849 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 28/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0137 - accuracy: 0.4667 - val_loss: 0.9950 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 29/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0254 - accuracy: 0.4952 - val_loss: 0.9739 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 30/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0355 - accuracy: 0.4857 - val_loss: 0.9636 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Warning: Length mismatch - y_test: 15, y_pred: 30
#
# BiLSTM Results:
# Accuracy: 0.4667
# Precision: 0.4444
# Recall: 0.4667
# F1-Score: 0.4470
#
# ==================================================
# Training GRU...
# ==================================================
# Epoch 1/30
# 14/14 [==============================] - 9s 105ms/step - loss: 1.6347 - accuracy: 0.3143 - val_loss: 1.0987 - val_accuracy: 0.1333 - lr: 0.0010
# Epoch 2/30
# 14/14 [==============================] - 0s 9ms/step - loss: 1.3098 - accuracy: 0.3333 - val_loss: 1.0983 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/30
# 14/14 [==============================] - 0s 9ms/step - loss: 1.3191 - accuracy: 0.3619 - val_loss: 1.0988 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.2895 - accuracy: 0.3905 - val_loss: 1.0992 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 5/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.1600 - accuracy: 0.4381 - val_loss: 1.0991 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 6/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.2018 - accuracy: 0.3524 - val_loss: 1.1000 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 7/30
# 14/14 [==============================] - 0s 9ms/step - loss: 1.1773 - accuracy: 0.3429 - val_loss: 1.1000 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 8/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1924 - accuracy: 0.3524 - val_loss: 1.0981 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 9/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1390 - accuracy: 0.3905 - val_loss: 1.0955 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 10/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.3043 - accuracy: 0.2381 - val_loss: 1.0932 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 11/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1757 - accuracy: 0.3524 - val_loss: 1.0901 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 12/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1461 - accuracy: 0.3810 - val_loss: 1.0879 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 13/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1197 - accuracy: 0.3619 - val_loss: 1.0866 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 14/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1226 - accuracy: 0.4000 - val_loss: 1.0845 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 15/30
# 14/14 [==============================] - 0s 16ms/step - loss: 1.0960 - accuracy: 0.3905 - val_loss: 1.0808 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 16/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1432 - accuracy: 0.3524 - val_loss: 1.0785 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 17/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0866 - accuracy: 0.3524 - val_loss: 1.0781 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 18/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1129 - accuracy: 0.3714 - val_loss: 1.0766 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 19/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1969 - accuracy: 0.3333 - val_loss: 1.0675 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 20/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1867 - accuracy: 0.3238 - val_loss: 1.0615 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 21/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1328 - accuracy: 0.4095 - val_loss: 1.0601 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 22/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0963 - accuracy: 0.4476 - val_loss: 1.0545 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 23/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0540 - accuracy: 0.4095 - val_loss: 1.0410 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 24/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0432 - accuracy: 0.4190 - val_loss: 1.0323 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 25/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1636 - accuracy: 0.3429 - val_loss: 1.0237 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 26/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0695 - accuracy: 0.4286 - val_loss: 1.0112 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 27/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.1365 - accuracy: 0.3429 - val_loss: 1.0015 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 28/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0985 - accuracy: 0.3619 - val_loss: 0.9940 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 29/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0641 - accuracy: 0.4381 - val_loss: 0.9835 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 30/30
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0600 - accuracy: 0.4476 - val_loss: 0.9765 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Warning: Length mismatch - y_test: 15, y_pred: 30
#
# GRU Results:
# Accuracy: 0.4667
# Precision: 0.3095
# Recall: 0.4667
# F1-Score: 0.3718
#
# ==================================================
# Training RNN...
# ==================================================
# Epoch 1/30
# 14/14 [==============================] - 5s 47ms/step - loss: 1.2701 - accuracy: 0.3524 - val_loss: 1.0958 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1824 - accuracy: 0.4476 - val_loss: 1.0953 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1967 - accuracy: 0.3524 - val_loss: 1.1094 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.2338 - accuracy: 0.3143 - val_loss: 1.1112 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 5/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1793 - accuracy: 0.3714 - val_loss: 1.1009 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 6/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1636 - accuracy: 0.3714 - val_loss: 1.0874 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 7/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1364 - accuracy: 0.4095 - val_loss: 1.0688 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 8/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1030 - accuracy: 0.3714 - val_loss: 1.0470 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 9/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.2634 - accuracy: 0.3524 - val_loss: 1.0371 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 10/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.1850 - accuracy: 0.3810 - val_loss: 1.0251 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 11/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.2398 - accuracy: 0.2952 - val_loss: 1.0006 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 12/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0449 - accuracy: 0.4476 - val_loss: 0.9718 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 13/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0190 - accuracy: 0.5048 - val_loss: 0.9581 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 14/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1113 - accuracy: 0.4000 - val_loss: 0.9617 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 15/30
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9987 - accuracy: 0.5238 - val_loss: 0.9658 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 16/30
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9993 - accuracy: 0.4571 - val_loss: 0.9671 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 17/30
# 14/14 [==============================] - 0s 14ms/step - loss: 1.0568 - accuracy: 0.3714 - val_loss: 0.9584 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 18/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0819 - accuracy: 0.4190 - val_loss: 0.9997 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 19/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1237 - accuracy: 0.4667 - val_loss: 0.9748 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 20/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0969 - accuracy: 0.4000 - val_loss: 0.9435 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 21/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1010 - accuracy: 0.3810 - val_loss: 0.9380 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 22/30
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0866 - accuracy: 0.4667 - val_loss: 0.9256 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 23/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0537 - accuracy: 0.4667 - val_loss: 0.9288 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 24/30
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9707 - accuracy: 0.5429 - val_loss: 0.9436 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 25/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0757 - accuracy: 0.4381 - val_loss: 0.9457 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 26/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0841 - accuracy: 0.4286 - val_loss: 0.9414 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 27/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1085 - accuracy: 0.4667 - val_loss: 0.9345 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 28/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.0248 - accuracy: 0.4381 - val_loss: 0.9283 - val_accuracy: 0.3333 - lr: 2.5000e-04
# Epoch 29/30
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9072 - accuracy: 0.5524 - val_loss: 0.9261 - val_accuracy: 0.3333 - lr: 2.5000e-04
# Epoch 30/30
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9390 - accuracy: 0.5333 - val_loss: 0.9220 - val_accuracy: 0.4000 - lr: 2.5000e-04
# Warning: Length mismatch - y_test: 15, y_pred: 30
#
# RNN Results:
# Accuracy: 0.6000
# Precision: 0.6905
# Recall: 0.6000
# F1-Score: 0.5945
#
# ==================================================
# Training CNN_RNN...
# ==================================================
# Epoch 1/30
# 14/14 [==============================] - 2s 27ms/step - loss: 1.0952 - accuracy: 0.4000 - val_loss: 1.1007 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 2/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.1014 - accuracy: 0.3905 - val_loss: 1.0811 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 3/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.1189 - accuracy: 0.3238 - val_loss: 1.0608 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 4/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.1031 - accuracy: 0.3619 - val_loss: 1.0478 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 5/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0756 - accuracy: 0.3524 - val_loss: 1.0349 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 6/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0727 - accuracy: 0.4381 - val_loss: 1.0267 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 7/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0360 - accuracy: 0.4286 - val_loss: 1.0087 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 8/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0174 - accuracy: 0.4857 - val_loss: 0.9846 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 9/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0032 - accuracy: 0.5429 - val_loss: 0.9643 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 10/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9876 - accuracy: 0.5619 - val_loss: 0.9380 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 11/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0000 - accuracy: 0.4476 - val_loss: 0.9311 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 12/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9556 - accuracy: 0.5714 - val_loss: 0.9385 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 13/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9187 - accuracy: 0.5524 - val_loss: 0.9475 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 14/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8875 - accuracy: 0.5524 - val_loss: 0.9157 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 15/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9341 - accuracy: 0.5619 - val_loss: 0.9143 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 16/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8581 - accuracy: 0.5905 - val_loss: 0.9193 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 17/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8416 - accuracy: 0.5905 - val_loss: 0.8753 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 18/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8192 - accuracy: 0.6190 - val_loss: 0.9026 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 19/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7966 - accuracy: 0.6571 - val_loss: 0.8949 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 20/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8347 - accuracy: 0.5619 - val_loss: 0.9224 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 21/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7988 - accuracy: 0.6762 - val_loss: 0.9141 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 22/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7941 - accuracy: 0.6286 - val_loss: 0.9076 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 23/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7489 - accuracy: 0.6762 - val_loss: 0.8610 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 24/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6800 - accuracy: 0.6857 - val_loss: 0.8949 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 25/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6974 - accuracy: 0.6667 - val_loss: 0.9304 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 26/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7657 - accuracy: 0.6000 - val_loss: 0.8701 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 27/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7531 - accuracy: 0.6190 - val_loss: 0.8640 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Epoch 28/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7499 - accuracy: 0.6762 - val_loss: 0.8376 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 29/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.7226 - accuracy: 0.6857 - val_loss: 0.8549 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Epoch 30/30
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7280 - accuracy: 0.6571 - val_loss: 0.9160 - val_accuracy: 0.4667 - lr: 5.0000e-04
# Warning: Length mismatch - y_test: 15, y_pred: 30
#
# CNN_RNN Results:
# Accuracy: 0.4667
# Precision: 0.4349
# Recall: 0.4667
# F1-Score: 0.4389
#
# ==================================================
# Training Keras_Deep...
# ==================================================
# Epoch 1/30
# 14/14 [==============================] - 3s 25ms/step - loss: 1.7212 - accuracy: 0.3238 - val_loss: 1.1094 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.6065 - accuracy: 0.3238 - val_loss: 1.1239 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.3021 - accuracy: 0.4381 - val_loss: 1.1315 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.3724 - accuracy: 0.3905 - val_loss: 1.1303 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 5/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1201 - accuracy: 0.4667 - val_loss: 1.1418 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 6/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.2814 - accuracy: 0.4286 - val_loss: 1.1449 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 7/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1557 - accuracy: 0.4667 - val_loss: 1.1494 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 8/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.2024 - accuracy: 0.4952 - val_loss: 1.1571 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 9/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.3659 - accuracy: 0.3524 - val_loss: 1.1529 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 10/30
# 14/14 [==============================] - 0s 6ms/step - loss: 1.2097 - accuracy: 0.4571 - val_loss: 1.1540 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 11/30
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1417 - accuracy: 0.4857 - val_loss: 1.1520 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Warning: Length mismatch - y_test: 15, y_pred: 30
#
# Keras_Deep Results:
# Accuracy: 0.3333
# Precision: 0.1111
# Recall: 0.3333
# F1-Score: 0.1667
#
# ==================================================
# Training Keras_Medium...
# ==================================================
# Epoch 1/30
# 14/14 [==============================] - 1s 18ms/step - loss: 1.1167 - accuracy: 0.3714 - val_loss: 1.0864 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 2/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.1123 - accuracy: 0.3905 - val_loss: 1.0699 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 3/30
# 14/14 [==============================] - 0s 11ms/step - loss: 1.0743 - accuracy: 0.4381 - val_loss: 1.0721 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 4/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0636 - accuracy: 0.4476 - val_loss: 1.0658 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 5/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0496 - accuracy: 0.4857 - val_loss: 1.0837 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 6/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.1023 - accuracy: 0.4190 - val_loss: 1.0607 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 7/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0671 - accuracy: 0.3810 - val_loss: 1.0542 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 8/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0657 - accuracy: 0.4857 - val_loss: 1.0445 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 9/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0512 - accuracy: 0.4476 - val_loss: 1.0289 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 10/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0633 - accuracy: 0.4190 - val_loss: 1.0083 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 11/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0067 - accuracy: 0.4190 - val_loss: 0.9777 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 12/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0016 - accuracy: 0.5048 - val_loss: 0.9696 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 13/30
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0685 - accuracy: 0.4381 - val_loss: 0.9873 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 14/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9942 - accuracy: 0.5048 - val_loss: 0.9646 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 15/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9735 - accuracy: 0.4952 - val_loss: 0.9947 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 16/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9556 - accuracy: 0.5048 - val_loss: 0.9496 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 17/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9493 - accuracy: 0.5333 - val_loss: 0.9318 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 18/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9337 - accuracy: 0.5238 - val_loss: 0.9188 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 19/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9097 - accuracy: 0.6095 - val_loss: 0.8870 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 20/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8543 - accuracy: 0.6190 - val_loss: 0.8895 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 21/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9119 - accuracy: 0.5048 - val_loss: 0.8931 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 22/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8673 - accuracy: 0.6286 - val_loss: 0.8632 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 23/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8910 - accuracy: 0.5524 - val_loss: 0.8645 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 24/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8332 - accuracy: 0.6095 - val_loss: 0.8928 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 25/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8278 - accuracy: 0.6095 - val_loss: 0.9364 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 26/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8868 - accuracy: 0.5048 - val_loss: 0.8920 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 27/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9595 - accuracy: 0.5333 - val_loss: 0.8820 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 28/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.8193 - accuracy: 0.6095 - val_loss: 0.8225 - val_accuracy: 0.5333 - lr: 5.0000e-04
# Epoch 29/30
# 14/14 [==============================] - 0s 4ms/step - loss: 0.7706 - accuracy: 0.6095 - val_loss: 0.8251 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 30/30
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7113 - accuracy: 0.6762 - val_loss: 0.8751 - val_accuracy: 0.4000 - lr: 5.0000e-04
# Warning: Length mismatch - y_test: 15, y_pred: 30
#
# Keras_Medium Results:
# Accuracy: 0.4000
# Precision: 0.3175
# Recall: 0.4000
# F1-Score: 0.3535

# %%
# Only run if we have results
if X is not None and hasattr(trainer, 'results') and trainer.results:
    # Compare models by accuracy
    comparison = trainer.compare_models(metric='accuracy')

    print("\n=== Model Performance Comparison ===")
    for model, score in comparison.items():
        print(f"{model}: {score:.4f}")
else:
    print("No results to compare")
# Out:
# === Model Performance Comparison ===
# RNN: 0.6000
# BiLSTM: 0.4667
# GRU: 0.4667
# CNN_RNN: 0.4667
# Keras_Medium: 0.4000
# CNN_LSTM: 0.3333
# LSTM: 0.3333
# Keras_Deep: 0.3333

# %%
# Only run if we have results
if X is not None and hasattr(trainer, 'results') and trainer.results:
    # Visualize comparison
    fig = viz.plot_model_comparison(trainer.results, metric='accuracy')
    plt.show()
else:
    print("Cannot visualize - no results")

# %%
# Only run if we have results
if X is not None and hasattr(trainer, 'results') and trainer.results:
    # Create comparison table
    comparison_data = []
    for name, result in trainer.results.items():
        if 'metrics' in result:
            comparison_data.append({
                'Model': name,
                'Accuracy': result['metrics']['accuracy'],
                'Precision': result['metrics']['precision'],
                'Recall': result['metrics']['recall'],
                'F1-Score': result['metrics']['f1_score']
            })

    df_comparison = pd.DataFrame(comparison_data)
    df_comparison = df_comparison.sort_values('Accuracy', ascending=False)
    display(df_comparison)
else:
    print("No data to display")
# Out:
#           Model  Accuracy  Precision    Recall  F1-Score
# 4           RNN  0.600000   0.690476  0.600000  0.594517
# 2        BiLSTM  0.466667   0.444444  0.466667  0.446970
# 3           GRU  0.466667   0.309524  0.466667  0.371795
# 5       CNN_RNN  0.466667   0.434921  0.466667  0.438889
# 7  Keras_Medium  0.400000   0.317460  0.400000  0.353535
# 0      CNN_LSTM  0.333333   0.222222  0.333333  0.264069
# 1          LSTM  0.333333   0.222222  0.333333  0.240196
# 6    Keras_Deep  0.333333   0.111111  0.333333  0.166667

# %%
# Get best model
best_name, best_model = trainer.get_best_model(metric='f1_score')
print(f"Best model: {best_name}")

# Get the original labels (not one-hot encoded)
# We need to get y_test from the original split or convert back
if len(y_test.shape) > 1 and y_test.shape[1] == 3:
    # Convert one-hot back to labels
    y_test_labels = np.argmax(y_test, axis=1)
    print(f"Converted y_test from one-hot {y_test.shape} to labels {y_test_labels.shape}")
else:
    y_test_labels = y_test

# Evaluate best model
if best_model:
    # Reshape input for sequence models
    if best_name in ['CNN_LSTM', 'LSTM', 'BiLSTM', 'GRU', 'RNN', 'CNN_RNN']:
        X_test_reshaped = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
        print(f"Reshaped X_test from {X_test.shape} to {X_test_reshaped.shape} for {best_name}")
    else:
        X_test_reshaped = X_test
    
    # Get predictions
    y_pred = best_model.predict(X_test_reshaped)
    print(f"Predictions shape: {y_pred.shape}")
    
    # Ensure same length (they should both be 30 now)
    if len(y_test_labels) != len(y_pred):
        print(f"Warning: Length mismatch - y_test_labels: {len(y_test_labels)}, y_pred: {len(y_pred)}")
        # This shouldn't happen now, but just in case
        min_len = min(len(y_test_labels), len(y_pred))
        y_test_labels = y_test_labels[:min_len]
        y_pred = y_pred[:min_len]
    
    # Classification report
    print("\nClassification Report:")
    print(classification_report(y_test_labels, y_pred, target_names=['Bad', 'Moderate', 'Good']))
    
    # Confusion matrix
    fig = best_model.plot_confusion_matrix(y_test_labels, y_pred, class_names=['Bad', 'Moderate', 'Good'])
    plt.show()
    
    # Also print accuracy
    accuracy = accuracy_score(y_test_labels, y_pred)
    print(f"\nFinal Accuracy: {accuracy:.4f}")
# Out:
# Best model: RNN
# Converted y_test from one-hot (15, 3) to labels (15,)
# Reshaped X_test from (30, 180) to (30, 1, 180) for RNN
# Predictions shape: (30,)
# Warning: Length mismatch - y_test_labels: 15, y_pred: 30
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          Bad       0.50      0.60      0.55         5
#     Moderate       1.00      0.40      0.57         5
#         Good       0.57      0.80      0.67         5
#
#     accuracy                           0.60        15
#    macro avg       0.69      0.60      0.59        15
# weighted avg       0.69      0.60      0.59        15
# Final Accuracy: 0.6000

# %%
# Only run if we have results
if X is not None and hasattr(trainer, 'results') and trainer.results:
    # Create ensemble prediction
    ensemble_results = trainer.create_ensemble_prediction(X_test)

    if ensemble_results:
        # Evaluate ensemble
        ensemble_accuracy = accuracy_score(y_test, ensemble_results['ensemble_pred'])
        voting_accuracy = accuracy_score(y_test, ensemble_results['voting_pred'])
        
        print(f"Ensemble (weighted) accuracy: {ensemble_accuracy:.4f}")
        print(f"Ensemble (voting) accuracy: {voting_accuracy:.4f}")
        
        # Compare with individual models
        individual_accuracies = [trainer.results[name]['metrics']['accuracy'] 
                                 for name in trainer.results.keys() 
                                 if 'metrics' in trainer.results[name]]
        
        print(f"\nIndividual models: {np.mean(individual_accuracies):.4f} ± {np.std(individual_accuracies):.4f}")
        print(f"Best individual: {np.max(individual_accuracies):.4f}")
else:
    print("Cannot create ensemble - no results")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 # Only run if we have results
#       2 if X is not None and hasattr(trainer, 'results') and trainer.results:
#       3     # Create ensemble prediction
# ----> 4     ensemble_results = trainer.create_ensemble_prediction(X_test)
#       6     if ensemble_results:
#       7         # Evaluate ensemble
#       8         ensemble_accuracy = accuracy_score(y_test, ensemble_results['ensemble_pred'])
#
# File c:\Graduation Project\V8\notebooks\..\models\model_trainer.py:264, in ModelTrainer.create_ensemble_prediction(self, X, weights)
#     257 else:
#     258     voting_pred = ensemble_pred
#     260 return {
#     261     'weighted_proba': weighted_proba,
#     262     'ensemble_pred': ensemble_pred,
#     263     'voting_pred': voting_pred,
# --> 264     'individual_predictions': predictions if predictions else [],
#     265     'valid_models': valid_models
#     266 }
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ### Save Results

# %%
# Only run if we have results
if X is not None and hasattr(trainer, 'results') and trainer.results:
    # Save all models
    summary = trainer.save_all_models()
    print("\nModels saved successfully!")
    
    # Print summary
    print("\nSummary of results:")
    for model_name, metrics in summary.items():
        print(f"\n{model_name}:")
        for metric_name, value in metrics.items():
            print(f"  {metric_name}: {value:.4f}")
else:
    print("No models to save")

# %% [markdown]
# ## Conclusion
# ### Based on the comparison above, we can identify the best model for our acting performance assessment system.

# %%
# Print final recommendations
if X is not None and hasattr(trainer, 'results') and trainer.results and ensemble_results:
    best_ensemble_accuracy = max(ensemble_accuracy, voting_accuracy)
    best_individual_accuracy = np.max(individual_accuracies) if individual_accuracies else 0
    
    print("\n" + "="*50)
    print("RECOMMENDATIONS")
    print("="*50)
    
    if best_ensemble_accuracy > best_individual_accuracy:
        print("✅ Use ensemble method for best performance")
        print(f"   Ensemble accuracy: {best_ensemble_accuracy:.4f}")
        print(f"   Best individual: {best_individual_accuracy:.4f}")
        
        # Show which ensemble method
        if ensemble_accuracy > voting_accuracy:
            print(f"\n   Best ensemble: Weighted averaging ({ensemble_accuracy:.4f})")
        else:
            print(f"\n   Best ensemble: Voting ({voting_accuracy:.4f})")
    else:
        print(f"✅ Use {best_name} for best performance")
        print(f"   Accuracy: {best_individual_accuracy:.4f}")
else:
    print("\nRun all previous cells first to get recommendations")
